# %% [markdown]
# ## 20250823数据正先导部分分析

# %% [markdown]
# ### 加载2d定位结果数据

# %%
import pandas as pd
import numpy as np

result = pd.read_csv('results/20250823172542_1505_result_yld_5.95e8_8.95e8_hann_2048_256_bandpass_hann_30e6_80e6.txt', sep=r'\s+')

# 对2d结果进行过滤筛选
filtered_result = result[
    (abs(result['t123']) < 1) &  
    (abs(result['Rcorr']) > 0.3) &  
    (result['Start_loc'] < 8.96e8) & 
    (result['Start_loc'] > 7.96e8) &
    (result.Azimuth > 250 ) & 
    (result.Azimuth < 300 ) & 
    (result.Elevation < 80) & 
    (result.Elevation > 55)
    ]
filtered_result
# Out:
#        Start_loc  peak   t12   t13   t23  cos_alpha_opt  cos_beta_opt  \
# 28904  796229701  2048 -48.1 -25.4  23.3      -0.474742     -0.043600
# 28942  796246989  2048 -43.8 -20.7  23.8      -0.440788     -0.064640
# 29342  799595240  2048 -45.8 -40.1   5.8      -0.399065      0.119000
# 29462  800268794  2048 -55.6 -40.9  14.3      -0.506676      0.070002
# 29463  800269155  2048 -55.8 -40.9  14.6      -0.509463      0.068252
# ...          ...   ...   ...   ...   ...            ...           ...
# 46574  868250278  2048 -24.4 -14.4  10.4      -0.236469     -0.007585
# 46575  868250629  2048 -24.0 -14.3  10.0      -0.231702     -0.005611
# 46579  868267977  2048 -23.5 -13.5  10.6      -0.229972     -0.012113
# 46580  868268475  2048 -23.5 -13.5  10.7      -0.230461     -0.012647
# 46581  868268733  2048 -23.4 -13.6  10.7      -0.229972     -0.012113
#
#           Azimuth  Elevation     Rcorr  t123
# 28904  264.752723  61.527301  0.315798   0.6
# 28942  261.657180  63.544519  0.305142   0.7
# 29342  286.604489  65.390611  0.344068   0.1
# 29462  277.866196  59.236939  0.383526  -0.4
# 29463  277.630422  59.068378  0.477708  -0.3
# ...           ...        ...       ...   ...
# 46574  268.162836  76.314596  0.759354   0.4
# 46575  268.612777  76.598691  0.636595   0.3
# 46579  266.984872  76.685827  0.651729   0.6
# 46580  266.858959  76.655380  0.738539   0.7
# 46581  266.984872  76.685827  0.695743   0.9
#
# [1493 rows x 11 columns]

# %% [markdown]
# ### 绘制二维结果图

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd 

# 提取数据
azimuth = filtered_result['Azimuth']
elevation = filtered_result['Elevation']

# 设置图形背景为白色
plt.figure(facecolor='white')
# 绘制单色散点图
plt.scatter(azimuth, elevation, 
            s=2,  # 点大小
            color='black',  # 单色设置
            alpha=0.8,  # 透明度
            marker='o')  # 点样式

# 设置标题和轴标签（深色文字）
plt.title('2d Lightning mapping', fontsize=16, fontweight='bold', color='black')
plt.xlabel('Azimuth / °', fontsize=12, color='black')
plt.ylabel('Elevation / °', fontsize=12, color='black')

# 设置坐标轴范围和刻度
plt.xlim(200, 300)
plt.xticks(range(200, 301, 20))  # 200到300，间隔20
plt.ylim(5, 85)
plt.yticks(range(5, 86, 10))  # 5到85，间隔10

# 获取当前坐标轴并设置样式
ax = plt.gca()
ax.set_facecolor('white')  # 坐标轴背景色与图形一致
ax.tick_params(axis='both', labelsize=11, colors='#333333')  # 刻度字体大小和颜色（深灰色）

# 设置坐标轴线条样式
for spine in ax.spines.values():
    spine.set_color('#333333')  # 坐标轴颜色（深灰色）
    spine.set_linewidth(1.2)    # 线条宽度

# 设置网格
ax.grid(True, linestyle='--', alpha=0.3)  # 虚线网格，低透明度
ax.set_frame_on(True)  # 显示坐标轴边框

# 调整布局并显示
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 分析梯级间隔

# %%
# 选出正先导数据
start_loc = 8.1e8
end_loc = 8.96e8
positive_lead_result = filtered_result[
    (filtered_result.Start_loc >= start_loc) &
    (filtered_result.Start_loc < end_loc)
    ]
time_diffs = np.diff(positive_lead_result.Start_loc)
max_diff_idx = np.argmax(time_diffs)
corresponding_start_loc = positive_lead_result.Start_loc.iloc[max_diff_idx]
print("最大的间隔位于:", corresponding_start_loc)

# 查看时间间隔大于某阈值的个数

thea = 3000
filtered_positive_time_diffs = time_diffs[time_diffs > thea]
filtered_positive_time_diffs = filtered_positive_time_diffs * 5 / 1e3
print(f"时间间隔大于{thea}的个数有：{len(filtered_positive_time_diffs)}")
print(f"正先导 {start_loc}-{end_loc} 阶段的时间间隔分布情况：\n",
      pd.DataFrame(data=filtered_positive_time_diffs).describe())
# Out:
# 最大的间隔位于: 853937261
# 时间间隔大于3000的个数有：193
# 正先导 810000000.0-896000000.0 阶段的时间间隔分布情况：
#                    0
# count    193.000000
# mean    1336.367306
# std     4113.889688
# min       15.080000
# 25%       21.240000
# 50%       41.375000
# 75%      166.280000
# max    33068.040000

# %%
# 计算梯级步长
## Step1: 拿到每个间隔对应的位置范围
filtered_indices = np.where(time_diffs > thea)
filtered_start_loc = positive_lead_result.Start_loc.iloc[filtered_indices[0]].values    # .values 将结果转为Numpy数组
start_locs = filtered_start_loc[:-1]  # 去掉最后一个元素
end_locs = filtered_start_loc[1:]    # 去掉第一个元素
# 拼接为元组列表
loc_tuples = list(zip(start_locs, end_locs))

durations = []
# Step2: 三维结果中筛选出对应的结果
for i, loc_tuple in enumerate(loc_tuples):
    durations.append((loc_tuple[1]-loc_tuple[0])*5/1e3)

durations_df = pd.DataFrame(data=durations)
print(f"正先导 {start_loc}-{end_loc} 阶段的梯级持续时间分布情况：\n",durations_df.describe())
# Out:
# 正先导 796000000.0-896000000.0 阶段的梯级持续时间分布情况：
#                    0
# count    689.000000
# mean     710.225864
# std     1353.754349
# min       15.245000
# 25%       42.675000
# 50%      134.315000
# 75%      758.180000
# max    13841.185000
